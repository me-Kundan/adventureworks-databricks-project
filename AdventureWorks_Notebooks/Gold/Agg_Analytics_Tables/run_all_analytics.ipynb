# %% [markdown]
# Execute Analysis Notebooks (sales_summary, customer_analysis, product_performance_analysis)

# %%
dbutils.notebook.run("sales_summary", 0)
dbutils.notebook.run("customer_analysis", 0)
dbutils.notebook.run("product_performance_analysis", 0)
