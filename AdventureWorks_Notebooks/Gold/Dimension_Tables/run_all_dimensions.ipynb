# %% [markdown]
# Execute Dimension Notebooks (Product, Customer, Date, Territory)

# %%
dbutils.notebook.run("dim_product", 0)
dbutils.notebook.run("dim_customer", 0)
dbutils.notebook.run("dim_date", 0)
dbutils.notebook.run("dim_territory", 0)
